# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
from data_profiling import ProfileReport
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 5
#       1 import warnings
#       2 warnings.filterwarnings("ignore")
#       3
#       4 import pandas as pd
# ----> 5 from data_profiling import ProfileReport
#
# File D:\Middlesex University Dubai\CST4275\cb-movie-reommender\.venv\Lib\site-packages\data_profiling\__init__.py:11
#       8 import importlib.util  # isort:skip # noqa
#       9 from warnings import warn
# ---> 11 from data_profiling.compare_reports import compare  # isort:skip # noqa
#      12 from data_profiling.controller import pandas_decorator  # isort:skip # noqa
#      13 from data_profiling.profile_report import ProfileReport  # isort:skip # noqa
#
# File D:\Middlesex University Dubai\CST4275\cb-movie-reommender\.venv\Lib\site-packages\data_profiling\compare_reports.py:12
#      10 from data_profiling.model import BaseDescription
# ...

# %%
movies_df = pd.read_parquet("../datasets/processed/movies_merged.parquet")
movies_profile = ProfileReport(movies_df, title="Movies Profiling Report")
movies_profile.to_widgets()

# %%
interactions_df = pd.read_csv(
    "../datasets/processed/interactions.csv", index_col=0
)
interactions_profile = ProfileReport(interactions_df, title="Interactions Profiling Report")
interactions_profile.to_widgets()
